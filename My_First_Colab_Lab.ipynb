# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshid12/SD/blob/main/My_First_Colab_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Markdown
# # My Data Science Journey
# ## Task 1: Basic Python Operations
# This cell demonstrates how to perform simple math in Colab.

# %%
seconds_in_a_day = 24 * 60 * 60
print(f"There are {seconds_in_a_day} seconds in a day.")
# Out:
# There are 86400 seconds in a day.

# %%
# !nvidia-smi
# Out:
# Sun Jan 11 14:04:17 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title("Sine Wave in Colab")
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
data = {
    'Day': ['Mon', 'Tue', 'Wed', 'Thu', 'Fri'],
    'Sales': [150, 200, 180, 220, 300]
}
df = pd.DataFrame(data)
print(df)
# Out:
#    Day  Sales
# 0  Mon    150
# 1  Tue    200
# 2  Wed    180
# 3  Thu    220
# 4  Fri    300

# %%
# This saves the file into your 'My Drive' folder
df.to_csv('/content/drive/MyDrive/ice_cream_sales.csv', index=False)
print("File saved successfully to Google Drive!")
# Out:
# File saved successfully to Google Drive!

# %%
# We use the 'wget' command to download a sample dataset
# !wget -O sample_data.csv https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv
# Out:
# --2026-01-11 14:19:20--  https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3858 (3.8K) [text/plain]
# Saving to: ‘sample_data.csv’
#
# sample_data.csv     100%[===================>]   3.77K  --.-KB/s    in 0s
#
# 2026-01-11 14:19:20 (72.0 MB/s) - ‘sample_data.csv’ saved [3858/3858]

# %%
# Load the downloaded file into a Pandas DataFrame
my_data = pd.read_csv('sample_data.csv')
# Show the first 5 rows
my_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#@title Data Visualization Settings
chart_color = "skyblue" #@param ["skyblue", "red", "green", "orange"]
line_thickness = 4 #@param {type:"slider", min:1, max:10, step:1}
df['Sales'].plot(kind='line', color=chart_color, lw=line_thickness)
# Out:
# <Axes: >
